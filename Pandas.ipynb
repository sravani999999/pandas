# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Datasets/main/hotel_bookings.csv")

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.tail(10)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %%
df.sample()
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 99759  City Hotel            0         37               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 99759            October                        42                         15
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 99759                        1                     1       3  ...
#
#        deposit_type  agent company days_in_waiting_list customer_type    adr  \
# 99759    No Deposit    9.0     NaN                    0     Transient  175.5
#
#        required_car_parking_spaces  total_of_special_requests  \
# 99759                            0                          1
#
#        reservation_status reservation_status_date
# 99759           Check-Out              10/17/2016
#
# [1 rows x 32 columns]

# %%
df.sample(10)
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 47174    City Hotel            0         44               2016
# 55705    City Hotel            1         50               2016
# 23893  Resort Hotel            0         94               2016
# 42132    City Hotel            0          9               2015
# 65432    City Hotel            1         97               2017
# 40092    City Hotel            1         92               2015
# 22679  Resort Hotel            0         18               2016
# 66781    City Hotel            1         25               2017
# 26866  Resort Hotel            0        241               2016
# 96477    City Hotel            0          3               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 47174           February                         7                         11
# 55705             August                        34                         19
# ...

# %%
df.sample(10)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 108372    City Hotel            0         82               2017
# 51673     City Hotel            1        158               2016
# 67395     City Hotel            1        151               2017
# 109532    City Hotel            0         62               2017
# 108443    City Hotel            0        121               2017
# 19115   Resort Hotel            0          2               2015
# 60279     City Hotel            1        277               2016
# 37295   Resort Hotel            0          8               2017
# 12108   Resort Hotel            1        135               2017
# 28228   Resort Hotel            0        248               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 108372              March                        12
# 51673                 May                        22
# 67395                 May                        18
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.describe(include="all")
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %%
import numpy as np

# %%
pd.Series(data=sample_list)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
labels=['w','x','y','z']
sample_list=[100,200,300,400]
array=np.array([1,2,3,4])
dic={'w':10,'x':20,'y':30,'z':40}

# %%
pd.Series(data=sample_list,index=labels)
# Out:
# w    100
# x    200
# y    300
# z    400
# dtype: int64

# %%
pd.Series(sample_list,array)
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# dtype: int64

# %%
pd.Series(dic)
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int64

# %%
sports1=pd.Series([1,2,3,4],index=['cricekt','football','Basketball','golf'])
sports1
# Out:
# cricekt       1
# football      2
# Basketball    3
# golf          4
# dtype: int64

# %%
sports1['football']
# Out:
# 2

# %%
sports2=pd.Series([11,2,3,4],index=['cricekt','football','Basketball','golf'])
sports2
# Out:
# cricekt       11
# football       2
# Basketball     3
# golf           4
# dtype: int64

# %%
sports1+sports2
# Out:
# cricekt       12
# football       4
# Basketball     6
# golf           8
# dtype: int64

# %%
sports3=pd.Series([1,2,3,4],index=['cricekt','football','Baseball','golf'])
sports3
# Out:
# cricekt     1
# football    2
# Baseball    3
# golf        4
# dtype: int64

# %%
sports2+sports3
# Out:
# Baseball       NaN
# Basketball     NaN
# cricekt       12.0
# football       4.0
# golf           8.0
# dtype: float64

# %%
import random

# %%
df1=pd.DataFrame(np.random.rand(8,5),index='A B C D E F G H'.split(),columns='Score1 Score2 Score3 Score4 Score5'.split())
df1
# Out:
#      Score1    Score2    Score3    Score4    Score5
# A  0.385677  0.828109  0.213137  0.643522  0.794279
# B  0.525900  0.179830  0.569349  0.095502  0.786205
# C  0.943416  0.445552  0.416271  0.503597  0.914436
# D  0.067299  0.755630  0.254018  0.155075  0.554176
# E  0.106710  0.125398  0.530705  0.691203  0.929539
# F  0.907781  0.704948  0.516677  0.263166  0.107914
# G  0.837844  0.354139  0.709341  0.638174  0.591258
# H  0.554058  0.949656  0.958047  0.426374  0.387669

# %%
df1['Score3']
# Out:
# A    0.213137
# B    0.569349
# C    0.416271
# D    0.254018
# E    0.530705
# F    0.516677
# G    0.709341
# H    0.958047
# Name: Score3, dtype: float64

# %%
df1[["Score1","Score2","Score3"]]
# Out:
#      Score1    Score2    Score3
# A  0.385677  0.828109  0.213137
# B  0.525900  0.179830  0.569349
# C  0.943416  0.445552  0.416271
# D  0.067299  0.755630  0.254018
# E  0.106710  0.125398  0.530705
# F  0.907781  0.704948  0.516677
# G  0.837844  0.354139  0.709341
# H  0.554058  0.949656  0.958047

# %%
df1["Score6"]=df1["Score1"]+df1["Score2"]
df1
# Out:
#      Score1    Score2    Score3    Score4    Score5    Score6
# A  0.385677  0.828109  0.213137  0.643522  0.794279  1.213787
# B  0.525900  0.179830  0.569349  0.095502  0.786205  0.705729
# C  0.943416  0.445552  0.416271  0.503597  0.914436  1.388968
# D  0.067299  0.755630  0.254018  0.155075  0.554176  0.822930
# E  0.106710  0.125398  0.530705  0.691203  0.929539  0.232108
# F  0.907781  0.704948  0.516677  0.263166  0.107914  1.612728
# G  0.837844  0.354139  0.709341  0.638174  0.591258  1.191982
# H  0.554058  0.949656  0.958047  0.426374  0.387669  1.503714

# %%
df2={'ID':['101','102','103','1025','390'],'Name':['John','Mercy','Aksh','Kavin','Lally'],'Profit':[20,56,78,9,456]}
df=pd.DataFrame(df2)
df
# Out:
#      ID   Name  Profit
# 0   101   John      20
# 1   102  Mercy      56
# 2   103   Aksh      78
# 3  1025  Kavin       9
# 4   390  Lally     456

# %%
df['ID']
# Out:
# 0     101
# 1     102
# 2     103
# 3    1025
# 4     390
# Name: ID, dtype: object

# %%
df[["ID","Name"]]
# Out:
#      ID   Name
# 0   101   John
# 1   102  Mercy
# 2   103   Aksh
# 3  1025  Kavin
# 4   390  Lally

# %%
df=df.drop('ID',axis=1)

# %%
df.drop(3)
# Out:
#     Name  Profit
# 0   John      20
# 1  Mercy      56
# 2   Aksh      78
# 4  Lally     456

# %%
df.drop(2,axis=0)
# Out:
#     Name  Profit
# 0   John      20
# 1  Mercy      56
# 3  Kavin       9
# 4  Lally     456
